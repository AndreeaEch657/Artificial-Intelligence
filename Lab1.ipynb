# %%
import csv
myList = []
with open(r"C:\Users\HP\Desktop\iris.data") as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    for row in readCSV:
     if len(row) == 5:
         myList.append([float(row[0]), float(row[1]), float(row[2]), float(row[3])])
            
import numpy as np
npArray = np.array(myList)

col0_min = np.min(npArray[:,0])
col1_min = np.min(npArray[:,1])
col2_min = np.min(npArray[:,2])
col3_min = np.min(npArray[:,3])

col0_max = np.max(npArray[:,0])
col1_max = np.max(npArray[:,1])
col2_max = np.max(npArray[:,2])
col3_max = np.max(npArray[:,3])

col0_avr = np.average(npArray[:,0])
col1_avr = np.average(npArray[:,1])
col2_avr = np.average(npArray[:,2])
col3_avr = np.average(npArray[:,3])

col0_med = np.median(npArray[:,0])
col1_med = np.median(npArray[:,1])
col2_med = np.median(npArray[:,2])
col3_med = np.median(npArray[:,3])

col0_norm = (npArray[:,0]-min(npArray[:,0])) / (max(npArray[:,0])-min(npArray[:,0]))
col1_norm = (npArray[:,1]-min(npArray[:,1])) / (max(npArray[:,1])-min(npArray[:,1]))
col2_norm = (npArray[:,2]-min(npArray[:,2])) / (max(npArray[:,2])-min(npArray[:,2]))
col3_norm = (npArray[:,3]-min(npArray[:,3])) / (max(npArray[:,3])-min(npArray[:,3]))

avrg = 0
weights = [0.2,1.1,-0.9,1]
s = 1.4
    
for x in range(4):
        avrg += (npArray[:,x]*weights[x])/s

print("col0_min = %f" % col0_min)       
print("col0_max = %f" %col0_max)
print("col0_avr = %f" %col0_avr)
print("col0_med = %f" %col0_med)
print(col0_norm)
print(avrg)
# Out:
# col0_min = 4.300000
# col0_max = 7.900000
# col0_avr = 5.843333
# col0_med = 5.800000
# [0.22222222 0.16666667 0.11111111 0.08333333 0.19444444 0.30555556
#  0.08333333 0.19444444 0.02777778 0.16666667 0.30555556 0.13888889
#  0.13888889 0.         0.41666667 0.38888889 0.30555556 0.22222222
#  0.38888889 0.22222222 0.30555556 0.22222222 0.08333333 0.22222222
#  0.13888889 0.19444444 0.19444444 0.25       0.25       0.11111111
#  0.13888889 0.30555556 0.25       0.33333333 0.16666667 0.19444444
#  0.33333333 0.16666667 0.02777778 0.22222222 0.19444444 0.05555556
#  0.02777778 0.19444444 0.22222222 0.13888889 0.22222222 0.08333333
#  0.27777778 0.19444444 0.75       0.58333333 0.72222222 0.33333333
#  0.61111111 0.38888889 0.55555556 0.16666667 0.63888889 0.25
#  0.19444444 0.44444444 0.47222222 0.5        0.36111111 0.66666667
#  0.36111111 0.41666667 0.52777778 0.36111111 0.44444444 0.5
#  0.55555556 0.5        0.58333333 0.63888889 0.69444444 0.66666667
# ...
